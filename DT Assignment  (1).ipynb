# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Reshabh Mehta\\Desktop\\datasets'

# %%
os.chdir('C:\\Users\\Reshabh Mehta\\Desktop\\datasets\\')
os.getcwd()
# Out:
# 'C:\\Users\\Reshabh Mehta\\Desktop\\datasets'

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Behavioural data science data.xlsx')

# %%
a1 = pd.read_excel('Behavioural data science data.xlsx', sheet_name='Sheet 2 Performance scorecard')
a1
# Out:
#     Unnamed: 0             Unnamed: 1        Unnamed: 2  Unnamed: 3  \
# 0          NaN                 Week 1               NaN         NaN
# 1          NaN  Performance Scorecard               NaN         NaN
# 2          NaN              Scored by  Mr Octopus (CEO)         NaN
# 3          NaN                    NaN               NaN         NaN
# 4          NaN           Contribution               NaN         NaN
# 5          NaN             Initiative               NaN         NaN
# 6          NaN    Bottleneck analysis               NaN         NaN
# 7          NaN                    NaN               NaN         NaN
# 8          NaN                Average               NaN         NaN
# 9          NaN                    NaN               NaN         NaN
# 10         NaN                    NaN               NaN         NaN
# 11         NaN                 Week 2               NaN         NaN
# 12         NaN  Performance Scorecard               NaN         NaN
# ...

# %% [markdown]
# # Analysis and vilsualistion for Performance scorecard

# %%
data = pd.DataFrame({
    'Week': ['Week 1', 'Week 2', 'Week 3'],
    'Contribution': [8.67, 7.67, 8.33],
    'Initiative': [7.67, 7.33, 7],
    'Bottleneck analysis': [7.67, 6.67, 7]
})

# %%
data
# Out:
#      Week  Contribution  Initiative  Bottleneck analysis
# 0  Week 1          8.67        7.67                 7.67
# 1  Week 2          7.67        7.33                 6.67
# 2  Week 3          8.33        7.00                 7.00

# %%
data.set_index('Week', inplace=True)

# %%
data.plot(kind='bar')
plt.title('Performance Scorecard')
plt.xlabel('Week')
plt.ylabel('Average Score')
plt.show()

# %% [markdown]
# # Analysis and visualistion for Happiness scorecard .

# %%
# Data for week 1.
week1_data ={'Neha':[6,7,6,7,9,8],'Amit':[8,10,9,9,9,10],'Sachin':[7,7,7,10,10,10]}
week1_df = pd.DataFrame.from_dict(week1_data)
week1_df
# Out:
#    Neha  Amit  Sachin
# 0     6     8       7
# 1     7    10       7
# 2     6     9       7
# 3     7     9      10
# 4     9     9      10
# 5     8    10      10

# %%
# Data for week 2 .
week2_data ={'Neha':[7,7,7,7,7,8],'Amit':[6,7,7,9,9,10],'Sachin':[9,9,9,9,10,10]}
week2_df = pd.DataFrame.from_dict(week2_data)
week2_df
# Out:
#    Neha  Amit  Sachin
# 0     7     6       9
# 1     7     7       9
# 2     7     7       9
# 3     7     9       9
# 4     7     9      10
# 5     8    10      10

# %%
# Data for week 3.
week3_data ={'Neha':[9,8,8,8,8,10],'Amit':[9,9,10,9,9,8],'Sachin':[9,9,8,10,9,9]}
week3_df = pd.DataFrame.from_dict(week3_data)
week3_df
# Out:
#    Neha  Amit  Sachin
# 0     9     9       9
# 1     8     9       9
# 2     8    10       8
# 3     8     9      10
# 4     8     9       9
# 5    10     8       9

# %%
print(week1_df) ,print(week2_df),print(week3_df)
# Out:
#    Neha  Amit  Sachin
# 0     6     8       7
# 1     7    10       7
# 2     6     9       7
# 3     7     9      10
# 4     9     9      10
# 5     8    10      10
#    Neha  Amit  Sachin
# 0     7     6       9
# 1     7     7       9
# 2     7     7       9
# 3     7     9       9
# 4     7     9      10
# 5     8    10      10
#    Neha  Amit  Sachin
# 0     9     9       9
# 1     8     9       9
# 2     8    10       8
# 3     8     9      10
# 4     8     9       9
# 5    10     8       9
# (None, None, None)

# %%
#concating data  and average scores for the three weeks .
avg_score = pd.concat([week1_df,week2_df,week3_df]).mean()
avg_score
# Out:
# Neha      7.611111
# Amit      8.722222
# Sachin    8.944444
# dtype: float64

# %%
ax = avg_score.plot(kind='bar', stacked=True, figsize=(10, 6))
ax.set_ylabel('Scores')
ax.set_title('Employee Performance Scorecard')
plt.show()

# %% [markdown]
# # Analysis and visualtion for Progress of candidates weekly .

# %% [markdown]
# ## Week 1

# %%
parameter =['Q1','Q2','Q3','Q4','Q5']
neha=[10,9,9,9,9]
amit =[8,7,8,8,8]
sachin=[6,4,7,7,6]

r1=range(len(parameter))
r2=[x+barWidth for x in r1]
r3=[x+barWidth for x in r2]

plt.bar(r1, neha, color='#1f77b4', width=.25, edgecolor='white', label='Neha')
plt.bar(r2, amit, color='#ff7f0e', width=.25, edgecolor='white', label='Amit')
plt.bar(r3, sachin, color='#2ca02c', width=.25, edgecolor='white', label='Sachin')

plt.xlabel('Parameters')
plt.ylabel('Scale 1 - 10')
plt.grid(True)
plt.legend()
plt.title('Efforts in Completing Projects and Personal Growth')

plt.show()

# %% [markdown]
# # Week 2

# %%
parameter = ['X', 'A, B and C', 'M, N and O', 'P, Q and R']
neha=[0,1,3,1]
amit =[1,1,3,3]
sachin=[1,1,3,3]

r1=range(len(parameter))
r2=[x+barWidth for x in r1]
r3=[x+barWidth for x in r2]

plt.bar(r1, neha, color='#1f77b4', width=.25, edgecolor='white', label='Neha')
plt.bar(r2, amit, color='#ff7f0e', width=.25, edgecolor='white', label='Amit')
plt.bar(r3, sachin, color='#2ca02c', width=.25, edgecolor='white', label='Sachin')

plt.xlabel('Parameters')
plt.ylabel('Score')
plt.xticks([r + barWidth for r in range(len(parameter))], parameter) 
plt.title('Test Scores')

plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # Week 3

# %%
parameter = ['% Pre-planned Work', '% Unplanned Work', '% Planned Work Completed', 'Contribution Improvement']
neha=[.75,.50, .85, 2]
amit =[1, .25, .85, 1.25]
sachin=[.5, .50, .85, 1.5]

r1=range(len(parameter))
r2=[x+barWidth for x in r1]
r3=[x+barWidth for x in r2]

plt.bar(r1, neha, color='#1f77b4', width=.25, edgecolor='white', label='Neha')
plt.bar(r2, amit, color='#ff7f0e', width=.25, edgecolor='white', label='Amit')
plt.bar(r3, sachin, color='#2ca02c', width=.25, edgecolor='white', label='Sachin')

plt.xlabel('Parameters')
plt.ylabel('Score')
plt.xticks([r + barWidth for r in range(len(parameter))], parameter,fontsize=6) 

plt.grid(True)
plt.legend()
plt.show()
